# %%
import os
import json
import cv2
import torch
import numpy as np
from PIL import Image
import chromadb
import clip
import shutil
import base64
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# %%
# Configuration
PROJECT_ROOT = "C:/Users/SANGLI Kenneth/Documents/project_root"
VIDEO_DIR = os.path.join(PROJECT_ROOT, "videos")
ANNOTATION_FILE = os.path.join(PROJECT_ROOT, "annotations.json")
SELECTED_SUBSET_FILE = os.path.join(PROJECT_ROOT, "annotations/selected_subset.json")
OUTPUT_DIR = os.path.join(PROJECT_ROOT, "output")
FPS = 1  # Extraire 1 frame par vidéo (frame centrale)
COLLECTION_NAME = "kinetics_700_subset"

# %%
# Créer le dossier de sortie
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Créer le client ChromaDB
client = chromadb.PersistentClient(path=os.path.join(PROJECT_ROOT, "chroma_db"))

# %%
# Charger le modèle CLIP
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
# Définir la fonction d'embedding pour ChromaDB
class ClipEmbeddingFunction:
    def __call__(self, input):
        if not isinstance(input, torch.Tensor):
            raise ValueError("Input to embedding function must be a torch.Tensor")
        with torch.no_grad():
            return clip_model.encode_image(input).cpu().numpy()

# %%
# Créer ou récupérer la collection ChromaDB
embedding_function = ClipEmbeddingFunction()
collection = client.get_or_create_collection(
    name=COLLECTION_NAME,
    embedding_function=embedding_function
)

def extract_single_frame(video_path):
    """Extrait la frame centrale d'une vidéo."""
    print(f"Extraction de la frame centrale de : {video_path}")
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Erreur : Impossible d'ouvrir la vidéo {video_path}")
        return None
    
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        print(f"Erreur : Aucune frame dans la vidéo {video_path}")
        cap.release()
        return None
    
    # Sélectionner la frame centrale
    central_frame_idx = total_frames // 2
    cap.set(cv2.CAP_PROP_POS_FRAMES, central_frame_idx)
    success, frame = cap.read()
    if not success:
        print(f"Erreur : Impossible de lire la frame centrale de {video_path}")
        cap.release()
        return None
    
    # Convertir en image PIL et sauvegarder
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_image = Image.fromarray(frame_rgb)
    frame_filename = os.path.join(OUTPUT_DIR, f"frame_{os.path.basename(video_path).split('.')[0]}.png")
    pil_image.save(frame_filename)
    print(f"Frame extraite : {frame_filename}")
    
    cap.release()
    return frame_filename

# %%
def load_kinetics_data(annotation_file, video_dir):
    """Charge les annotations et extrait une frame par vidéo."""
    with open(annotation_file, 'r') as f:
        annotations = json.load(f)
    
    frame_paths = []
    labels = []
    video_ids = []
    
    for video_id, info in annotations.items():
        video_path = os.path.join(video_dir, info['path'])
        label = info['label']
        frame_path = extract_single_frame(video_path)
        if frame_path is None:
            print(f"Aucune frame extraite pour {video_path}. Passage à la suivante.")
            continue
        frame_paths.append(frame_path)
        labels.append(label)
        video_ids.append(video_id)
    
    return frame_paths, labels, video_ids

def encode_image(image_path):
    """Encode une image avec CLIP et normalise l'embedding."""
    image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
    with torch.no_grad():
        image_features = clip_model.encode_image(image)
    # Normalisation explicite
    image_embedding = image_features / image_features.norm(dim=-1, keepdim=True)
    return image_embedding.cpu().numpy()

def encode_text(text):
    """Encode un texte avec CLIP et normalise l'embedding."""
    text_inputs = clip.tokenize([text]).to(device)
    with torch.no_grad():
        text_features = clip_model.encode_text(text_inputs)
    # Normalisation explicite
    text_embedding = text_features / text_features.norm(dim=-1, keepdim=True)
    return text_embedding.cpu().numpy()

def calculate_metrics(similarity_matrix, labels, text_labels):
    """Calcule les métriques de performance."""
    num_samples = similarity_matrix.shape[0]
    
    precision_at_1 = 0
    precision_at_3 = 0
    correct_distances = []
    incorrect_distances = []
    
    for i in range(num_samples):
        true_label = labels[i]
        true_idx = text_labels.index(true_label)
        
        similarities = similarity_matrix[i]
        sorted_indices = np.argsort(similarities)[::-1]
        
        if sorted_indices[0] == true_idx:
            precision_at_1 += 1
        if true_idx in sorted_indices[:3]:
            precision_at_3 += 1
        
        correct_distances.append(similarities[true_idx])
        incorrect_indices = [idx for idx in range(len(text_labels)) if idx != true_idx]
        incorrect_distances.extend(similarities[incorrect_indices])
    
    precision_at_1 = precision_at_1 / num_samples
    precision_at_3 = precision_at_3 / num_samples
    avg_correct_distance = np.mean(correct_distances)
    avg_incorrect_distance = np.mean(incorrect_distances)
    
    return {
        "precision@1": precision_at_1,
        "precision@3": precision_at_3,
        "avg_correct_distance": avg_correct_distance,
        "avg_incorrect_distance": avg_incorrect_distance
    }

# %%
def generate_results_html(frame_paths, text_queries, labels, video_ids, similarity_matrix, metrics):
    """Génère un fichier HTML avec les résultats."""
    def image_to_data_uri(img_path):
        try:
            with open(img_path, "rb") as img_file:
                encoded = base64.b64encode(img_file.read()).decode('utf-8')
                return encoded
        except Exception as e:
            print(f"Erreur lors de l'encodage de {img_path} : {e}")
            return None

    similarity_matrix_np = similarity_matrix
    
    html = """
    <html>
    <head>
        <title>CLIP Results with Kinetics-700</title>
        <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
        <style>
            body {{ padding: 20px; }}
            table {{ width: 100%; }}
            th, td {{ vertical-align: middle; text-align: center; }}
        </style>
    </head>
    <body>
    <div class="container">
        <h1 class="my-4">CLIP Results with Kinetics-700</h1>
        <h2>Métriques</h2>
        <table class="table table-bordered">
            <tr><th>Précision@1</th><td>{0:.2f}</td></tr>
            <tr><th>Précision@3</th><td>{1:.2f}</td></tr>
            <tr><th>Distance moyenne (correcte)</th><td>{2:.2f}</td></tr>
            <tr><th>Distance moyenne (incorrecte)</th><td>{3:.2f}</td></tr>
        </table>
        <h2>Résultats détaillés</h2>
        <table class="table table-bordered table-striped">
        <thead class="table-light">
        <tr>
            <th>Video ID</th>
            <th>Frame</th>
            <th>Ground Truth Label</th>
            <th>Best Matched Text</th>
    """.format(
        metrics['precision@1'],
        metrics['precision@3'],
        metrics['avg_correct_distance'],
        metrics['avg_incorrect_distance']
    )

    for text in text_queries:
        html += f'<th>{text}</th>'
    html += "</tr></thead><tbody>"
    
    for i, (img_path, label, video_id) in enumerate(zip(frame_paths, labels, video_ids)):
        img_data_uri = image_to_data_uri(img_path)
        img_display = f"<img src='data:image/png;base64,{img_data_uri}' width='100'>" if img_data_uri else "Image indisponible"
        
        similarities = similarity_matrix_np[i, :]
        best_match_index = np.argmax(similarities)
        best_matched_text = text_queries[best_match_index]
        
        html += f"""
        <tr>
            <td>{video_id}</td>
            <td>{img_display}</td>
            <td>{label}</td>
            <td>{best_matched_text}</td>
        """
        for j, score in enumerate(similarities):
            html += f"<td class='bg-info'><b>{score:.2f}</b></td>" if j == best_match_index else f"<td>{score:.2f}</td>"
        html += "</tr>"
    
    html += """
        </tbody>
        </table>
    </div>
    </body>
    </html>
    """
    
    with open(os.path.join(OUTPUT_DIR, "results_kinetics.html"), "w") as f:
        f.write(html)
    print(f"Résultats sauvegardés dans {os.path.join(OUTPUT_DIR, 'results_kinetics.html')}")

def plot_similarity_distribution(correct_distances, incorrect_distances):
    """Affiche la distribution des similarités."""
    plt.figure(figsize=(10, 6))
    plt.hist(correct_distances, bins=30, alpha=0.5, label='Correct Pairs', color='green')
    plt.hist(incorrect_distances, bins=30, alpha=0.5, label='Incorrect Pairs', color='red')
    plt.title('Distribution des similarités cosinus')
    plt.xlabel('Similarité cosinus')
    plt.ylabel('Fréquence')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(OUTPUT_DIR, 'similarity_distribution.png'))
    plt.close()
    print(f"Graphique sauvegardé dans {os.path.join(OUTPUT_DIR, 'similarity_distribution.png')}")

def search_similar_images(query, top_k=5):
    """Recherche les images les plus similaires à une requête textuelle dans ChromaDB."""
    # Encoder et normaliser la requête
    query_embedding = encode_text(query)
    
    # Effectuer la recherche dans ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding.tolist()[0]],
        n_results=top_k,
        include=["metadatas", "embeddings"]  # Récupérer les embeddings pour recalculer la similarité
    )
    
    # Extraire les résultats
    image_paths = []
    similarities = []
    labels = []
    video_ids = []
    
    # Recalculer la similarité manuellement
    for id_, embedding, metadata in zip(results['ids'][0], results['embeddings'][0], results['metadatas'][0]):
        # Convertir les embeddings en numpy arrays
        stored_embedding = np.array(embedding).reshape(1, -1)
        # Recalculer la similarité cosinus
        similarity = cosine_similarity(query_embedding, stored_embedding)[0][0]
        # S'assurer que la similarité est dans la plage [0, 1]
        similarity = max(0, min(1, similarity))
        
        image_paths.append(metadata['frame'])
        similarities.append(similarity)
        labels.append(metadata['label'])
        video_ids.append(id_)
    
    # Trier les résultats par similarité décroissante
    sorted_results = sorted(zip(image_paths, similarities, labels, video_ids), key=lambda x: x[1], reverse=True)
    image_paths, similarities, labels, video_ids = zip(*sorted_results) if sorted_results else ([], [], [], [])
    
    return list(image_paths), list(similarities), list(labels), list(video_ids)

def display_search_results(query, image_paths, similarities, labels, video_ids):
    """Génère un fichier HTML pour afficher les résultats de la recherche."""
    def image_to_data_uri(img_path):
        try:
            with open(img_path, "rb") as img_file:
                encoded = base64.b64encode(img_file.read()).decode('utf-8')
                return encoded
        except Exception as e:
            print(f"Erreur lors de l'encodage de {img_path} : {e}")
            return None

    html = """
    <html>
    <head>
        <title>Recherche d'images similaires - Kinetics-700</title>
        <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
        <style>
            body {{ padding: 20px; }}
            table {{ width: 100%; }}
            th, td {{ vertical-align: middle; text-align: center; }}
        </style>
    </head>
    <body>
    <div class="container">
        <h1 class="my-4">Résultats de la recherche pour : "{}"</h1>
        <table class="table table-bordered table-striped">
        <thead class="table-light">
        <tr>
            <th>Video ID</th>
            <th>Frame</th>
            <th>Label</th>
            <th>Similarité</th>
        </tr>
        </thead>
        <tbody>
    """.format(query)
    
    for img_path, similarity, label, video_id in zip(image_paths, similarities, labels, video_ids):
        img_data_uri = image_to_data_uri(img_path)
        img_display = f"<img src='data:image/png;base64,{img_data_uri}' width='100'>" if img_data_uri else "Image indisponible"
        
        html += f"""
        <tr>
            <td>{video_id}</td>
            <td>{img_display}</td>
            <td>{label}</td>
            <td>{similarity:.4f}</td>
        </tr>
        """
    
    html += """
        </tbody>
        </table>
    </div>
    </body>
    </html>
    """
    
    output_file = os.path.join(OUTPUT_DIR, f"search_results_{query.replace(' ', '_')}.html")
    with open(output_file, "w") as f:
        f.write(html)
    print(f"Résultats de la recherche sauvegardés dans {output_file}")

# %%
def main():
    # Étape 1 : Charger les données Kinetics-700
    print("Étape 1 : Chargement des données Kinetics-700...")
    frame_paths, labels, video_ids = load_kinetics_data(ANNOTATION_FILE, VIDEO_DIR)
    if not frame_paths:
        print("Erreur : Aucune frame n'a été extraite.")
        return
    
    # Étape 2 : Définir les queries descriptives
    print("Étape 2 : Génération des queries descriptives...")
    concepts = sorted(list(set(labels)))
    query_dict = {
        "playing basketball": "A group of people playing basketball on an outdoor court with a hoop",
        "playing soccer": "A group of people kicking a soccer ball on a grassy field with goalposts",
        "cooking": "A person in a kitchen chopping vegetables on a cutting board",
        "painting": "A person painting a canvas with colorful paints in a studio",
        "swimming": "A person swimming in a blue pool under the sun",
        "reading a book": "A person sitting on a couch reading a book in a cozy room",
        "playing guitar": "A person playing an acoustic guitar in a park",
        "riding a bike": "A person riding a bike on a sunny trail with trees",
        "doing yoga": "A person doing yoga on a mat in a calm studio",
        "writing on a whiteboard": "A person writing on a whiteboard in a classroom",
        # Complétez avec les autres classes...
    }
    text_queries = [query_dict.get(c, f"A person performing the action of {c} in a typical setting") for c in concepts]
    print(f"Concepts : {concepts}")
    print(f"Queries : {text_queries}")

    # Étape 3 : Calculer les embeddings et stocker dans ChromaDB
    print("Étape 3 : Calcul des embeddings et stockage dans ChromaDB...")
    image_embeddings = []
    for i, frame_path in enumerate(frame_paths):
        embedding = encode_image(frame_path)
        image_embeddings.append(embedding[0])
        collection.add(
            ids=[video_ids[i]],
            embeddings=[embedding[0].tolist()],
            metadatas=[{"frame": frame_path, "label": labels[i]}]
        )
        print(f"Embedding ajouté pour {video_ids[i]}")
    
    # Étape 4 : Calculer la matrice de similarité
    print("Étape 4 : Calcul de la matrice de similarité...")
    text_embeddings = [encode_text(query)[0] for query in text_queries]
    similarity_matrix = cosine_similarity(image_embeddings, text_embeddings)
    
    # Étape 5 : Calculer les métriques
    print("Étape 5 : Calcul des métriques...")
    metrics = calculate_metrics(similarity_matrix, labels, concepts)
    print("Métriques :")
    print(f"Précision@1 : {metrics['precision@1']:.2f}")
    print(f"Précision@3 : {metrics['precision@3']:.2f}")
    print(f"Distance moyenne (correcte) : {metrics['avg_correct_distance']:.2f}")
    print(f"Distance moyenne (incorrecte) : {metrics['avg_incorrect_distance']:.2f}")
    
    # Étape 6 : Visualiser les résultats
    print("Étape 6 : Génération des visualisations...")
    generate_results_html(frame_paths, text_queries, labels, video_ids, similarity_matrix, metrics)
    
    # Étape 7 : Afficher la distribution des similarités
    correct_distances = [similarity_matrix[i, concepts.index(labels[i])] for i in range(len(labels))]
    incorrect_distances = [similarity_matrix[i, j] for i in range(len(labels)) for j in range(len(concepts)) if j != concepts.index(labels[i])]
    plot_similarity_distribution(correct_distances, incorrect_distances)
    
    # Étape 8 : Interface de recherche interactive
    print("Étape 8 : Recherche interactive...")
    while True:
        query = input("Entrez une requête textuelle (ou 'quitter' pour arrêter) : ")
        if query.lower() == 'quitter':
            break
        if not query.strip():
            print("Erreur : La requête ne peut pas être vide.")
            continue
        
        top_k = input("Combien de résultats voulez-vous (par défaut 5) ? ")
        try:
            top_k = int(top_k) if top_k.strip() else 5
            if top_k <= 0:
                raise ValueError
        except ValueError:
            print("Erreur : Entrez un nombre positif. Utilisation de la valeur par défaut (5).")
            top_k = 5
        
        image_paths, similarities, labels, video_ids = search_similar_images(query, top_k)
        if not image_paths:
            print("Aucun résultat trouvé. Vérifiez la collection ChromaDB.")
            continue
        
        display_search_results(query, image_paths, similarities, labels, video_ids)
        print(f"Ouvrez {os.path.join(OUTPUT_DIR, f'search_results_{query.replace(' ', '_')}.html')} pour voir les résultats.")

if __name__ == "__main__":
    main()
# Out:
# Étape 1 : Chargement des données Kinetics-700...
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_1.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_1.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_2.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_2.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_3.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_3.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_4.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_4.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_5.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_5.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_6.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_6.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_7.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_7.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_8.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_8.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_9.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_9.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_10.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_10.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_11.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_11.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_12.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_12.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_13.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_13.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_14.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_14.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_15.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_15.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_16.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_16.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_17.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_17.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_18.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_18.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_19.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_19.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_20.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_20.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_21.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_21.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_22.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_22.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_23.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_23.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_24.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_24.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_25.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_25.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_26.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_26.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_27.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_27.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_28.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_28.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_29.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_29.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_30.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_30.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_31.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_31.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_32.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_32.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_33.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_33.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_34.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_34.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_35.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_35.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_36.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_36.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_37.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_37.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_38.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_38.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_39.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_39.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_40.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_40.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_41.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_41.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_42.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_42.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_43.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_43.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_44.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_44.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_45.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_45.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_46.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_46.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_47.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_47.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_48.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_48.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_49.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_49.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_50.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_50.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_51.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_51.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_52.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_52.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_53.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_53.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_54.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_54.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_55.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_55.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_56.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_56.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_57.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_57.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_58.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_58.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_59.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_59.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_60.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_60.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_61.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_61.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_62.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_62.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_63.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_63.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_64.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_64.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_65.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_65.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_66.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_66.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_67.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_67.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_68.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_68.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_69.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_69.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_70.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_70.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_71.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_71.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_72.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_72.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_73.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_73.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_74.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_74.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_75.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_75.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_76.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_76.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_77.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_77.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_78.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_78.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_79.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_79.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_80.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_80.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_81.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_81.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_82.mp4
# Erreur : Impossible de lire la frame centrale de C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_82.mp4
# Aucune frame extraite pour C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_82.mp4. Passage à la suivante.
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_83.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_83.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_84.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_84.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_85.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_85.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_86.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_86.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_87.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_87.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_88.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_88.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_89.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_89.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_90.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_90.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_91.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_91.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_92.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_92.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_93.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_93.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_94.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_94.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_95.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_95.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_96.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_96.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_97.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_97.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_98.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_98.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_99.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_99.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_100.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_100.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_101.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_101.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_102.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_102.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_103.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_103.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_104.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_104.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_105.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_105.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_106.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_106.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_107.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_107.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_108.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_108.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_109.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_109.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_110.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_110.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_111.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_111.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_112.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_112.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_113.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_113.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_114.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_114.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_115.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_115.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_116.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_116.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_117.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_117.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_118.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_118.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_119.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_119.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_120.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_120.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_121.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_121.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_122.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_122.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_123.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_123.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_124.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_124.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_125.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_125.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_126.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_126.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_127.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_127.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_128.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_128.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_129.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_129.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_130.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_130.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_131.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_131.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_132.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_132.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_133.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_133.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_134.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_134.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_135.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_135.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_136.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_136.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_137.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_137.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_138.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_138.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_139.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_139.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_140.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_140.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_141.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_141.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_142.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_142.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_143.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_143.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_144.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_144.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_145.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_145.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_146.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_146.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_147.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_147.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_148.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_148.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_149.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_149.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_150.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_150.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_151.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_151.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_152.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_152.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_153.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_153.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_154.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_154.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_155.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_155.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_156.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_156.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_157.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_157.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_158.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_158.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_159.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_159.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_160.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_160.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_161.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_161.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_162.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_162.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_163.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_163.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_164.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_164.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_165.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_165.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_166.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_166.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_167.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_167.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_168.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_168.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_169.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_169.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_170.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_170.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_171.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_171.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_172.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_172.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_173.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_173.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_174.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_174.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_175.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_175.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_176.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_176.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_177.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_177.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_178.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_178.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_179.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_179.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_180.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_180.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_181.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_181.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_182.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_182.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_183.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_183.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_184.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_184.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_185.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_185.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_186.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_186.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_187.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_187.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_188.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_188.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_189.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_189.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_190.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_190.png
# Extraction de la frame centrale de : C:/Users/SANGLI Kenneth/Documents/project_root\videos\video_191.mp4
# Frame extraite : C:/Users/SANGLI Kenneth/Documents/project_root\output\frame_video_191.png
# Étape 2 : Génération des queries descriptives...
# Concepts : ['applauding', 'bathing dog', 'beatboxing', 'being in zero gravity', 'bench pressing', 'bobsledding', 'carving ice', 'celebrating', 'checking tires', 'checking watch', 'chiseling wood', 'clay pottery making', 'closing door', 'country line dancing', 'cutting nails', 'diving cliff', 'doing jigsaw puzzle', 'filling cake', 'getting a haircut', 'giving or receiving award', 'golf chipping', 'gospel singing in church', 'headbutting', 'hoverboarding', 'juggling fire', 'kitesurfing', 'land sailing', 'long jump', 'opening bottle (not wine)', 'opening refrigerator', 'parasailing', 'playing clarinet', 'playing cricket', 'playing scrabble', 'playing squash or racquetball', 'punching person (boxing)', 'putting on sari', 'sharpening pencil', 'skipping stone', 'smoking', 'snowkiting', 'springboard diving', 'sword swallowing', 'tackling', 'testifying', 'threading needle', 'using bagging machine', 'wading through water', 'wood burning (art)']
# Queries : ['A person performing the action of applauding in a typical setting', 'A person performing the action of bathing dog in a typical setting', 'A person performing the action of beatboxing in a typical setting', 'A person performing the action of being in zero gravity in a typical setting', 'A person performing the action of bench pressing in a typical setting', 'A person performing the action of bobsledding in a typical setting', 'A person performing the action of carving ice in a typical setting', 'A person performing the action of celebrating in a typical setting', 'A person performing the action of checking tires in a typical setting', 'A person performing the action of checking watch in a typical setting', 'A person performing the action of chiseling wood in a typical setting', 'A person performing the action of clay pottery making in a typical setting', 'A person performing the action of closing door in a typical setting', 'A person performing the action of country line dancing in a typical setting', 'A person performing the action of cutting nails in a typical setting', 'A person performing the action of diving cliff in a typical setting', 'A person performing the action of doing jigsaw puzzle in a typical setting', 'A person performing the action of filling cake in a typical setting', 'A person performing the action of getting a haircut in a typical setting', 'A person performing the action of giving or receiving award in a typical setting', 'A person performing the action of golf chipping in a typical setting', 'A person performing the action of gospel singing in church in a typical setting', 'A person performing the action of headbutting in a typical setting', 'A person performing the action of hoverboarding in a typical setting', 'A person performing the action of juggling fire in a typical setting', 'A person performing the action of kitesurfing in a typical setting', 'A person performing the action of land sailing in a typical setting', 'A person performing the action of long jump in a typical setting', 'A person performing the action of opening bottle (not wine) in a typical setting', 'A person performing the action of opening refrigerator in a typical setting', 'A person performing the action of parasailing in a typical setting', 'A person performing the action of playing clarinet in a typical setting', 'A person performing the action of playing cricket in a typical setting', 'A person performing the action of playing scrabble in a typical setting', 'A person performing the action of playing squash or racquetball in a typical setting', 'A person performing the action of punching person (boxing) in a typical setting', 'A person performing the action of putting on sari in a typical setting', 'A person performing the action of sharpening pencil in a typical setting', 'A person performing the action of skipping stone in a typical setting', 'A person performing the action of smoking in a typical setting', 'A person performing the action of snowkiting in a typical setting', 'A person performing the action of springboard diving in a typical setting', 'A person performing the action of sword swallowing in a typical setting', 'A person performing the action of tackling in a typical setting', 'A person performing the action of testifying in a typical setting', 'A person performing the action of threading needle in a typical setting', 'A person performing the action of using bagging machine in a typical setting', 'A person performing the action of wading through water in a typical setting', 'A person performing the action of wood burning (art) in a typical setting']
# Étape 3 : Calcul des embeddings et stockage dans ChromaDB...
# Embedding ajouté pour video_1
# Embedding ajouté pour video_2
# Embedding ajouté pour video_3
# Embedding ajouté pour video_4
# Embedding ajouté pour video_5
# Embedding ajouté pour video_6
# Embedding ajouté pour video_7
# Embedding ajouté pour video_8
# Embedding ajouté pour video_9
# Embedding ajouté pour video_10
# Embedding ajouté pour video_11
# Embedding ajouté pour video_12
# Embedding ajouté pour video_13
# Embedding ajouté pour video_14
# Embedding ajouté pour video_15
# Embedding ajouté pour video_16
# Embedding ajouté pour video_17
# Embedding ajouté pour video_18
# Embedding ajouté pour video_19
# Embedding ajouté pour video_20
# Embedding ajouté pour video_21
# Embedding ajouté pour video_22
# Embedding ajouté pour video_23
# Embedding ajouté pour video_24
# Embedding ajouté pour video_25
# Embedding ajouté pour video_26
# Embedding ajouté pour video_27
# Embedding ajouté pour video_28
# Embedding ajouté pour video_29
# Embedding ajouté pour video_30
# Embedding ajouté pour video_31
# Embedding ajouté pour video_32
# Embedding ajouté pour video_33
# Embedding ajouté pour video_34
# Embedding ajouté pour video_35
# Embedding ajouté pour video_36
# Embedding ajouté pour video_37
# Embedding ajouté pour video_38
# Embedding ajouté pour video_39
# Embedding ajouté pour video_40
# Embedding ajouté pour video_41
# Embedding ajouté pour video_42
# Embedding ajouté pour video_43
# Embedding ajouté pour video_44
# Embedding ajouté pour video_45
# Embedding ajouté pour video_46
# Embedding ajouté pour video_47
# Embedding ajouté pour video_48
# Embedding ajouté pour video_49
# Embedding ajouté pour video_50
# Embedding ajouté pour video_51
# Embedding ajouté pour video_52
# Embedding ajouté pour video_53
# Embedding ajouté pour video_54
# Embedding ajouté pour video_55
# Embedding ajouté pour video_56
# Embedding ajouté pour video_57
# Embedding ajouté pour video_58
# Embedding ajouté pour video_59
# Embedding ajouté pour video_60
# Embedding ajouté pour video_61
# Embedding ajouté pour video_62
# Embedding ajouté pour video_63
# Embedding ajouté pour video_64
# Embedding ajouté pour video_65
# Embedding ajouté pour video_66
# Embedding ajouté pour video_67
# Embedding ajouté pour video_68
# Embedding ajouté pour video_69
# Embedding ajouté pour video_70
# Embedding ajouté pour video_71
# Embedding ajouté pour video_72
# Embedding ajouté pour video_73
# Embedding ajouté pour video_74
# Embedding ajouté pour video_75
# Embedding ajouté pour video_76
# Embedding ajouté pour video_77
# Embedding ajouté pour video_78
# Embedding ajouté pour video_79
# Embedding ajouté pour video_80
# Embedding ajouté pour video_81
# Embedding ajouté pour video_83
# Embedding ajouté pour video_84
# Embedding ajouté pour video_85
# Embedding ajouté pour video_86
# Embedding ajouté pour video_87
# Embedding ajouté pour video_88
# Embedding ajouté pour video_89
# Embedding ajouté pour video_90
# Embedding ajouté pour video_91
# Embedding ajouté pour video_92
# Embedding ajouté pour video_93
# Embedding ajouté pour video_94
# Embedding ajouté pour video_95
# Embedding ajouté pour video_96
# Embedding ajouté pour video_97
# Embedding ajouté pour video_98
# Embedding ajouté pour video_99
# Embedding ajouté pour video_100
# Embedding ajouté pour video_101
# Embedding ajouté pour video_102
# Embedding ajouté pour video_103
# Embedding ajouté pour video_104
# Embedding ajouté pour video_105
# Embedding ajouté pour video_106
# Embedding ajouté pour video_107
# Embedding ajouté pour video_108
# Embedding ajouté pour video_109
# Embedding ajouté pour video_110
# Embedding ajouté pour video_111
# Embedding ajouté pour video_112
# Embedding ajouté pour video_113
# Embedding ajouté pour video_114
# Embedding ajouté pour video_115
# Embedding ajouté pour video_116
# Embedding ajouté pour video_117
# Embedding ajouté pour video_118
# Embedding ajouté pour video_119
# Embedding ajouté pour video_120
# Embedding ajouté pour video_121
# Embedding ajouté pour video_122
# Embedding ajouté pour video_123
# Embedding ajouté pour video_124
# Embedding ajouté pour video_125
# Embedding ajouté pour video_126
# Embedding ajouté pour video_127
# Embedding ajouté pour video_128
# Embedding ajouté pour video_129
# Embedding ajouté pour video_130
# Embedding ajouté pour video_131
# Embedding ajouté pour video_132
# Embedding ajouté pour video_133
# Embedding ajouté pour video_134
# Embedding ajouté pour video_135
# Embedding ajouté pour video_136
# Embedding ajouté pour video_137
# Embedding ajouté pour video_138
# Embedding ajouté pour video_139
# Embedding ajouté pour video_140
# Embedding ajouté pour video_141
# Embedding ajouté pour video_142
# Embedding ajouté pour video_143
# Embedding ajouté pour video_144
# Embedding ajouté pour video_145
# Embedding ajouté pour video_146
# Embedding ajouté pour video_147
# Embedding ajouté pour video_148
# Embedding ajouté pour video_149
# Embedding ajouté pour video_150
# Embedding ajouté pour video_151
# Embedding ajouté pour video_152
# Embedding ajouté pour video_153
# Embedding ajouté pour video_154
# Embedding ajouté pour video_155
# Embedding ajouté pour video_156
# Embedding ajouté pour video_157
# Embedding ajouté pour video_158
# Embedding ajouté pour video_159
# Embedding ajouté pour video_160
# Embedding ajouté pour video_161
# Embedding ajouté pour video_162
# Embedding ajouté pour video_163
# Embedding ajouté pour video_164
# Embedding ajouté pour video_165
# Embedding ajouté pour video_166
# Embedding ajouté pour video_167
# Embedding ajouté pour video_168
# Embedding ajouté pour video_169
# Embedding ajouté pour video_170
# Embedding ajouté pour video_171
# Embedding ajouté pour video_172
# Embedding ajouté pour video_173
# Embedding ajouté pour video_174
# Embedding ajouté pour video_175
# Embedding ajouté pour video_176
# Embedding ajouté pour video_177
# Embedding ajouté pour video_178
# Embedding ajouté pour video_179
# Embedding ajouté pour video_180
# Embedding ajouté pour video_181
# Embedding ajouté pour video_182
# Embedding ajouté pour video_183
# Embedding ajouté pour video_184
# Embedding ajouté pour video_185
# Embedding ajouté pour video_186
# Embedding ajouté pour video_187
# Embedding ajouté pour video_188
# Embedding ajouté pour video_189
# Embedding ajouté pour video_190
# Embedding ajouté pour video_191
# Étape 4 : Calcul de la matrice de similarité...
# Étape 5 : Calcul des métriques...
# Métriques :
# Précision@1 : 0.43
# Précision@3 : 0.53
# Distance moyenne (correcte) : 0.25
# Distance moyenne (incorrecte) : 0.20
# Étape 6 : Génération des visualisations...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 93
#      90         print(f"Ouvrez {os.path.join(OUTPUT_DIR, f'search_results_{query.replace(' ', '_')}.html')} pour voir les résultats.")
#      92 if __name__ == "__main__":
# ---> 93     main()
#
# Cell In[10], line 58, in main()
#      56 # Étape 6 : Visualiser les résultats
#      57 print("Étape 6 : Génération des visualisations...")
# ---> 58 generate_results_html(frame_paths, text_queries, labels, video_ids, similarity_matrix, metrics)
#      60 # Étape 7 : Afficher la distribution des similarités
#      61 correct_distances = [similarity_matrix[i, concepts.index(labels[i])] for i in range(len(labels))]
#
# Cell In[9], line 43, in generate_results_html(frame_paths, text_queries, labels, video_ids, similarity_matrix, metrics)
#      10         return None
#      12 similarity_matrix_np = similarity_matrix
#      14 html = """
#      15 <html>
#      16 <head>
#      17     <title>CLIP Results with Kinetics-700</title>
#      18     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
#      19     <style>
#      20         body { padding: 20px; }
#      21         table { width: 100%; }
#      22         th, td { vertical-align: middle; text-align: center; }
#      23     </style>
#      24 </head>
#      25 <body>
#      26 <div class="container">
#      27     <h1 class="my-4">CLIP Results with Kinetics-700</h1>
#      28     <h2>Métriques</h2>
#      29     <table class="table table-bordered">
#      30         <tr><th>Précision@1</th><td>{:.2f}</td></tr>
#      31         <tr><th>Précision@3</th><td>{:.2f}</td></tr>
#      32         <tr><th>Distance moyenne (correcte)</th><td>{:.2f}</td></tr>
#      33         <tr><th>Distance moyenne (incorrecte)</th><td>{:.2f}</td></tr>
#      34     </table>
#      35     <h2>Résultats détaillés</h2>
#      36     <table class="table table-bordered table-striped">
#      37     <thead class="table-light">
#      38     <tr>
#      39         <th>Video ID</th>
#      40         <th>Frame</th>
#      41         <th>Ground Truth Label</th>
#      42         <th>Best Matched Text</th>
# ---> 43 """.format(metrics['precision@1'], metrics['precision@3'], metrics['avg_correct_distance'], metrics['avg_incorrect_distance'])
#      45 for text in text_queries:
#      46     html += f'<th>{text}</th>'
#
# KeyError: ' padding'
